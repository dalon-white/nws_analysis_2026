# %% [markdown]
# Purpose:
# Map data of cows and cow purpose across Mexico
#     -Use data from 2022
# Create a visualization output. A static map of all types plus an interactive map with the ability to filter by type of cow and purpose. HTML based.

# %%
#import load data function
from src.load_data import load_csv

#import clean data function
from src.clean_data import clean_data

#import others
import pandas as pd

# %% [markdown]
# get data from data/raw/mexico_cattle_data_2022.csv

# %%
# Out:
# C:\Users\Dalon.White\OneDrive - USDA\Desktop\Projects\New World screwworm\nws_analysis_2026\nws_analysis_2026

# %%
#clean data
# Example DataFrame

# Specify the numeric columns (3:11 corresponds to column indices 2 to 10 in Python)
numeric_columns = df.columns[3:11]  # Adjust based on your DataFrame

# Clean the data
cleaned_df = clean_data(df, numeric_columns)
# Out:
# C:\Users\Dalon.White\OneDrive - USDA\Desktop\Projects\New World screwworm\nws_analysis_2026\nws_analysis_2026\data\raw\mexico_cattle_data_2022.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 5
#       3 print(file_path)
#       4 # Load the data
# ----> 5 mexico_cattle_data = pd.read_csv(file_path)
#       7 mexico_cattle_data.head()
#
# ...

# %%
import os
print(os.name)
print(5*2)
print(os.name)
# Out:
# nt
# 10
# nt
